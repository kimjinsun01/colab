# %% [markdown]
# <a href="https://colab.research.google.com/github/kimjinsun01/colab/blob/main/Lession4(5).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 모험을 떠나는 거북이

# %% [markdown]
# # 새 섹션

# %%
#!pip3 install Colabturtle
import ColabTurtle.Turtle as turtle
turtle.initializeTurtle()

x = int(input("이동할 x의 위치 : "))
y = int(input("이동할 y의 위치 : "))
text = input("쓰고 싶은 글자 ==>")

turtle.penup()
turtle.goto(x,y)
turtle.write(text)
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
#         <text x="300" y="300" fill="white" text-anchor="start" style="font-size:12px;font-family:'Arial';">베트남</text>
#         <g visibility=visible transform="rotate(360,300,300) translate(282, 282)">
# <path style=" stroke:none;fill-rule:evenodd;fill:white;fill-opacity:1;" d="M 18.214844 0.632812 C 16.109375 1.800781 15.011719 4.074219 15.074219 7.132812 L 15.085938 7.652344 L 14.785156 7.496094 C 13.476562 6.824219 11.957031 6.671875 10.40625 7.066406 C 8.46875 7.550781 6.515625 9.15625 4.394531 11.992188 C 3.0625 13.777344 2.679688 14.636719 3.042969 15.027344 L 3.15625 15.152344 L 3.519531 15.152344 C 4.238281 15.152344 4.828125 14.886719 8.1875 13.039062 C 9.386719 12.378906 10.371094 11.839844 10.378906 11.839844 C 10.386719 11.839844 10.355469 11.929688 10.304688 12.035156 C 9.832031 13.09375 9.257812 14.820312 8.96875 16.078125 C 7.914062 20.652344 8.617188 24.53125 11.070312 27.660156 C 11.351562 28.015625 11.363281 27.914062 10.972656 28.382812 C 8.925781 30.84375 7.945312 33.28125 8.238281 35.1875 C 8.289062 35.527344 8.28125 35.523438 8.917969 35.523438 C 10.941406 35.523438 13.074219 34.207031 15.136719 31.6875 C 15.359375 31.417969 15.328125 31.425781 15.5625 31.574219 C 16.292969 32.042969 18.023438 32.964844 18.175781 32.964844 C 18.335938 32.964844 19.941406 32.210938 20.828125 31.71875 C 20.996094 31.625 21.136719 31.554688 21.136719 31.558594 C 21.203125 31.664062 21.898438 32.414062 22.222656 32.730469 C 23.835938 34.300781 25.5625 35.132812 27.582031 35.300781 C 27.90625 35.328125 27.9375 35.308594 28.007812 34.984375 C 28.382812 33.242188 27.625 30.925781 25.863281 28.425781 L 25.542969 27.96875 L 25.699219 27.785156 C 28.945312 23.960938 29.132812 18.699219 26.257812 11.96875 L 26.207031 11.84375 L 27.945312 12.703125 C 31.53125 14.476562 32.316406 14.800781 33.03125 14.800781 C 33.976562 14.800781 33.78125 13.9375 32.472656 12.292969 C 28.519531 7.355469 25.394531 5.925781 21.921875 7.472656 L 21.558594 7.636719 L 21.578125 7.542969 C 21.699219 6.992188 21.761719 5.742188 21.699219 5.164062 C 21.496094 3.296875 20.664062 1.964844 19.003906 0.855469 C 18.480469 0.503906 18.457031 0.5 18.214844 0.632812"/>
# </g>
#       </svg>
# 이동할 x의 위치 : 300
# 이동할 y의 위치 : 300
# 쓰고 싶은 글자 ==>베트남

# %%
num = 99
if num < 100 :
  print("100보다 작습니다.")
# Out:
# 100보다 작습니다.

# %%
num = int(input("정수를 입력 : "))
if (num % 2) == 0 :
  print(num,"짝수입니다.")
else :
  print(num,"홀수입니다.")
# Out:
# 정수를 입력 : 1
# 1 홀수입니다.

# %% [markdown]
# 랜덤 함수
# import random

# %%
import random

r = random.randint(1,45)
print(r)
# Out:
# 42

# %%
import random

com_number = random.randint(1,45)
print("** 컴퓨터가 생각한 숫자를 맞추는 게임 **")
print("숫자는 1부터 45까지입니다.")
while com_number != user_number :
  user_number = int(input("숫자를 입력 : "))
  if com_number > user_number :
    print("입력한 숫자가 적습니다.")
  elif com_number < user_number :
    print("입력한 숫자가 더 큽니다.")
  else :
    print("정답^^7")
# Out:
# ** 컴퓨터가 생각한 숫자를 맞추는 게임 **
# 숫자는 1부터 45까지입니다.
# 숫자를 입력 : 20
# 입력한 숫자가 더 큽니다.
# 숫자를 입력 : 10
# 입력한 숫자가 적습니다.
# 숫자를 입력 : 15
# 입력한 숫자가 더 큽니다.
# 숫자를 입력 : 13
# 입력한 숫자가 더 큽니다.
# 숫자를 입력 : 12
# 정답^^7

# %%
import random
com_player = random.choice(["가위","바위","보"])
print("** 가위 바위 보 게임 **")
user_player = input("가위/바위/보 중 하나를 입력하세요 ==> ")
print(com_player, user_player)
# Out:
# ** 가위 바위 보 게임 **
# 가위/바위/보 중 하나를 입력하세요 ==> 바위
# 보 바위

# %%
import random
com_player = random.choice(["가위","바위","보"])
print("** 가위 바위 보 게임 **")
user_player = input("가위/바위/보 중 하나를 입력하세요 ==> ")
count = 7
while count > 0:
  user_player = input("가위/바위/보 중 하나를 입력하세요 ==>")
  if (com_player == user_player) :
    print("비겼다.")
  elif ((com_player == "가위") and (user_player == "바위")) or \
  ((com_player == "바위") and (user_player == "가위")) or \
  ((com_player == "보") and (user_player == "가위")) :
    print("이겼다.")
  else :
    print("졌다.")
  count = count - 1
# Out:
# ** 가위 바위 보 게임 **
# 가위/바위/보 중 하나를 입력하세요 ==> 보
# 가위/바위/보 중 하나를 입력하세요 ==>가위
# 이겼다.
# 가위/바위/보 중 하나를 입력하세요 ==>주먹
# 졌다.
# 가위/바위/보 중 하나를 입력하세요 ==>보
# 비겼다.
# 가위/바위/보 중 하나를 입력하세요 ==>가위
# 이겼다.
# 가위/바위/보 중 하나를 입력하세요 ==>가위
# 이겼다.
# 가위/바위/보 중 하나를 입력하세요 ==>가위
# 이겼다.
# 가위/바위/보 중 하나를 입력하세요 ==>보
# 비겼다.

# %%
num = int(input("숫자를 입력 ==> "))

if num > 100 :
  if num < 1000 :
    print("100보다 크고 1000보다 작군요.")
  else :
    print("와~ 1000보다 크군요.")
else :
  print("음~ 100보다 작군요.")
# Out:
# 숫자를 입력 ==> 150
# 100보다 크고 1000보다 작군요.

# %%
score = int(input("점수를 입력 ==> "))

if score >= 90 :
  print("A",end='')
else :
  if score >= 80 :
    print("B", end='')
  else :
    if score >= 70 :
      print("C", end='')
    else :
      if score >= 60 :
        print("D", end='')
      else :
        print("F", end='')
print("학점입니다.")
# Out:
# 점수를 입력 ==> 77
# C학점입니다.

# %%
score = int(input("점수를 입력 ==> "))

if score >= 90 :
  print("A",end='')
elif score >= 80 :
    print("B", end='')
elif score >= 70 :
      print("C", end='')
elif score >= 60 :
        print("D", end='')
else :
        print("F", end='')
print("학점입니다.")
# Out:
# 점수를 입력 ==> 80
# B학점입니다.

# %%
age = int(input("나이를 입력 ==> "))

if age >= 18:
  print("즐거운 시간 되세요 ^^")
else :
  print("집에 갈 시간이네요!")

print("협조 감사합니다.")
# Out:
# 나이를 입력 ==> 17
# 집에 갈 시간이네요!
# 협조 감사합니다.

# %%
import random
myHand = input("나의 가위/바위/보 ==>")
comHand = random.choice(["가위","바위","보"])
print("컴퓨터의 가위/바위/보 ==>", comHand)

if myHand == comHand :
  print("비겼습니다. --.--")

elif (myHand == "가위" and comHand == "보") or \
     (myHand == "바위" and comHand == "가위") or \
     (myHand == "보" and comHand == "바위"):
    print("이겼습니다.")
else :
  print("졌습니다.")
# Out:
# 나의 가위/바위/보 ==>가위
# 컴퓨터의 가위/바위/보 ==> 바위
# 졌습니다.

# %%
#!pip3 install Colabturtle
import ColabTurtle.Turtle as turtle

import random
print(turtle.DEFAULT_WINDOW_SIZE)
turtle.initializeTurtle()

while True :
  turtle.left(random.randint(0,360))
  turtle.color((random.randint(0,255),random.randint(0,255),random.randint(0,255)))
  turtle.forward(random.randint(10,100))
  if 800 <= turtle.getx() or turtle.getx() <= 0 or \
  500 <= turtle.gety() or turtle.gety() <=0:
    turtle.goto(400,250)
  print(turtle.getx(), turtle.gety())
# Out:
# (800, 500)
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
#         <line x1="400" y1="250" x2="439.319" y2="277.532" stroke-linecap="round" style="stroke:rgb(159,75,85);stroke-width:4"/><line x1="439.319" y1="277.532" x2="429.776" y2="217.283" stroke-linecap="round" style="stroke:rgb(217,95,47);stroke-width:4"/><line x1="429.776" y1="217.283" x2="409.204" y2="245.599" stroke-linecap="round" style="stroke:rgb(167,47,220);stroke-width:4"/><line x1="409.204" y1="245.599" x2="394.35" y2="243.511" stroke-linecap="round" style="stroke:rgb(158,23,167);stroke-width:4"/><line x1="394.35" y1="243.511" x2="418.606" y2="158.92" stroke-linecap="round" style="stroke:rgb(113,240,47);stroke-width:4"/><line x1="418.606" y1="158.92" x2="454.967" y2="224.516" stroke-linecap="round" style="stroke:rgb(192,147,159);stroke-width:4"/><line x1="454.967" y1="224.516" x2="497.52" y2="257.762" stroke-linecap="round" style="stroke:rgb(255,164,117);stroke-width:4"/><line x1="497.52" y1="257.762" x2="569.876" y2="284.098" stroke-linecap="round" style="stroke:rgb(28,106,211);stroke-width:4"/><line x1="569.876" y1="284.098" x2="533.898" y2="282.842" stroke-linecap="round" style="stroke:rgb(101,181,156);stroke-width:4"/><line x1="533.898" y1="282.842" x2="486.927" y2="284.482" stroke-linecap="round" style="stroke:rgb(194,34,174);stroke-width:4"/><line x1="486.927" y1="284.482" x2="511.996" y2="254.606" stroke-linecap="round" style="stroke:rgb(53,211,173);stroke-width:4"/><line x1="511.996" y1="254.606" x2="490.658" y2="212.729" stroke-linecap="round" style="stroke:rgb(209,197,146);stroke-width:4"/><line x1="490.658" y1="212.729" x2="534.073" y2="182.329" stroke-linecap="round" style="stroke:rgb(30,138,162);stroke-width:4"/><line x1="534.073" y1="182.329" x2="528.339" y2="167.392" stroke-linecap="round" style="stroke:rgb(97,73,16);stroke-width:4"/><line x1="528.339" y1="167.392" x2="530.712" y2="235.351" stroke-linecap="round" style="stroke:rgb(76,52,110);stroke-width:4"/><line x1="530.712" y1="235.351" x2="519.136" y2="308.44" stroke-linecap="round" style="stroke:rgb(137,215,182);stroke-width:4"/><line x1="519.136" y1="308.44" x2="536.043" y2="306.663" stroke-linecap="round" style="stroke:rgb(110,145,228);stroke-width:4"/><line x1="536.043" y1="306.663" x2="542.852" y2="324.401" stroke-linecap="round" style="stroke:rgb(98,33,4);stroke-width:4"/><line x1="542.852" y1="324.401" x2="609.266" y2="382.134" stroke-linecap="round" style="stroke:rgb(78,29,115);stroke-width:4"/><line x1="609.266" y1="382.134" x2="678.432" y2="326.124" stroke-linecap="round" style="stroke:rgb(160,144,237);stroke-width:4"/><line x1="678.432" y1="326.124" x2="730.173" y2="405.798" stroke-linecap="round" style="stroke:rgb(46,65,12);stroke-width:4"/><line x1="730.173" y1="405.798" x2="667.173" y2="405.798" stroke-linecap="round" style="stroke:rgb(150,192,14);stroke-width:4"/><line x1="667.173" y1="405.798" x2="686.744" y2="490.568" stroke-linecap="round" style="stroke:rgb(1,81,255);stroke-width:4"/><line x1="686.744" y1="490.568" x2="694.834" y2="496.446" stroke-linecap="round" style="stroke:rgb(37,131,42);stroke-width:4"/><line x1="694.834" y1="496.446" x2="689.114" y2="414.646" stroke-linecap="round" style="stroke:rgb(99,102,109);stroke-width:4"/><line x1="689.114" y1="414.646" x2="671.554" y2="368.901" stroke-linecap="round" style="stroke:rgb(66,136,42);stroke-width:4"/><line x1="671.554" y1="368.901" x2="714.855" y2="343.901" stroke-linecap="round" style="stroke:rgb(229,48,225);stroke-width:4"/><line x1="714.855" y1="343.901" x2="669.107" y2="339.093" stroke-linecap="round" style="stroke:rgb(164,22,174);stroke-width:4"/><line x1="669.107" y1="339.093" x2="627.572" y2="287.801" stroke-linecap="round" style="stroke:rgb(67,13,168);stroke-width:4"/><line x1="627.572" y1="287.801" x2="664.902" y2="355.147" stroke-linecap="round" style="stroke:rgb(240,159,131);stroke-width:4"/><line x1="664.902" y1="355.147" x2="654.714" y2="403.076" stroke-linecap="round" style="stroke:rgb(122,7,147);stroke-width:4"/><line x1="654.714" y1="403.076" x2="725.209" y2=" ...
# 439.319 277.532
# 429.776 217.283
# 409.204 245.599
# 394.35 243.511
# 418.606 158.92
# 454.967 224.516
# 497.52 257.762
# 569.876 284.098
# 533.898 282.842
# 486.927 284.482
# 511.996 254.606
# 490.658 212.729
# 534.073 182.329
# 528.339 167.392
# 530.712 235.351
# 519.136 308.44
# 536.043 306.663
# 542.852 324.401
# 609.266 382.134
# 678.432 326.124
# 730.173 405.798
# 667.173 405.798
# 686.744 490.568
# 694.834 496.446
# 689.114 414.646
# 671.554 368.901
# 714.855 343.901
# 669.107 339.093
# 627.572 287.801
# 664.902 355.147
# 654.714 403.076
# 725.209 471.153
# 763.442 385.28
# 716.34 371.774
# 690.477 407.371
# 708.594 474.986
# 619.305 437.085
# 400 250
# 406.973 219.795
# 422.946 231.831
# 352.475 223.178
# 280.023 160.196
# 247.903 206.069
# 299.811 191.185
# 357.781 129.02
# 325.661 174.893
# 367.264 160.568
# 347.98 183.549
# 357.331 192.58
# 408.777 268.851
# 431.553 272.052
# 416.271 287.877
# 331.174 317.178
# 284.594 263.594
# 279.945 253.625
# 289.67 263.696
# 320.85 270.894
# 298.621 293.913
# 294.517 305.189
# 337.584 253.864
# 374.404 238.235
# 303.105 228.215
# 248.603 248.052
# 322.174 181.808
# 318.739 164.139
# 311.527 232.761
# 308.91 282.692
# 211.044 277.563
# 185.768 311.106
# 262.669 289.055
# 309.898 315.235
# 390.712 344.649
# 321.821 361.825
# 254.08 367.752
# 244.158 316.707
# 264.075 299.995
# 196.177 279.237
# 198.265 264.383
# 230.22 293.156
# 294.306 330.156
# 269.937 393.639
# 325.297 311.564
# 289.589 357.269
# 259.332 346.851
# 235.936 326.513
# 219.079 368.236
# 244.831 411.094
# 225.381 431.236
# 301.277 427.258
# 325.262 426.42
# 314.386 421.349
# 316.058 437.261
# 333.772 416.884
# 295.472 347.789
# 285.313 323.856
# 352.838 301.916
# 346.735 313.394
# 375.489 336.679
# 376.466 308.696
# 377.929 294.773
# 403.787 292.055
# 500.728 288.67
# 429.447 324.989
# 411.226 350.069
# 439.44 311.236
# 518.455 323.751
# 447.05 338.929
# 422.993 326.671
# 465.125 362.024
# 460.567 375.261
# 478.943 443.842
# 453.122 395.28
# 457.96 375.874
# 437.96 410.515
# 492.953 360.999
# 408.309 388.502
# 345.939 420.281
# 316.528 374.993
# 323.531 441.626
# 306.279 407.768
# 290.152 449.779
# 267.988 478.147
# 307.114 486.463
# 400 250
# 362.283 254.631
# 291.812 263.284
# 227.445 272.33
# 210.757 275.574
# 144.757 275.574
# 166.6 259.704
# 153.529 239.576
# 139.751 261.625
# 203.791 277.592
# 191.073 297.945
# 162.128 392.619
# 67.467 417.983
# 21.146 383.078
# 1.602 475.024
# 400 250
# 406.84 231.206
# 462.949 285.389
# 513.466 227.276
# 514.46 208.302
# 469.826 197.174
# 460.314 287.675
# 376.519 281.815
# 301.919 245.43
# 261.68 172.837
# 346.873 212.563
# 335.471 249.859
# 380.143 311.344
# 332.914 337.524
# 264.764 348.318
# 321.395 307.173
# 405.075 299.852
# 358.446 262.093
# 324.588 244.841
# 325.738 233.901
# 414.25 243.204
# 405.22 191.994
# 374.69 172.917
# 415.988 113.938
# 367.141 59.688
# 400 250
# 465.054 315.054
# 472.368 308.234
# 448.885 323.484
# 498.213 393.931
# 456.202 410.058
# 482.404 466.249
# 505.279 431.025
# 505.279 397.025
# 598.997 368.373
# 560.153 405.885
# 636.201 461.137
# 609.751 424.731
# 605.674 385.945
# 601.077 404.381
# 541.19 420.428
# 503.592 357.855
# 603.044 347.402
# 535.044 347.402
# 582.68 324.168
# 568.315 363.635
# 519.463 421.854
# 556.765 414.603
# 491.975 345.124
# 476.546 354.395
# 470.532 423.132
# 400 250
# 469.448 235.238
# 436.666 196.17
# 406.372 180.734
# 362.138 149.761
# 415.489 213.343
# 469.637 192.558
# 461.368 163.72
# 493.388 171.703
# 465.022 181.47
# 395.483 209.565
# 418.233 184.298
# 411.943 159.07
# 422.789 70.733
# 414.654 89.004
# 387.696 50.504
# 429.765 81.069
# 397.585 111.077
# 477.173 164.76
# 483.709 154.696
# 473.134 130.944
# 415.858 188.22
# 514.021 169.139
# 519.613 160.849
# 531.741 203.145
# 505.741 203.145
# 413.25 212.866
# 407.516 197.929
# 391.563 244.259
# 378.04 247.882
# 358.241 228.083
# 392.426 258.863
# 452.761 181.638
# 377.501 171.061
# 319.948 196.685
# 298.219 200.127
# 281.818 181.259
# 265.249 174.226
# 315.766 232.339
# 336.472 155.065
# 307.061 200.353
# 286.699 163.619
# 263.081 188.077
# 228.915 264.815
# 240.886 297.704
# 227.104 249.641
# 141.313 255.64
# 206.1 268.233
# 223.59 228.951
# 207.628 258.971
# 279.021 287.816
# 303.35 197.019
# 307.066 267.922
# 350.257 186.691
# 409.176 189.779
# 394.329 125.471
# 373.486 122.912
# 401.018 162.231
# 374.046 95.474
# 307.867 159.383
# 269.84 230.902
# 257.964 225.614
# 263.811 244.74
# 229.156 170.423
# 233.497 145.803
# 248.114 139.295
# 250.697 213.25
# 213.507 133.495
# 228.2 171.772
# 267.175 162.774
# 215.571 226.5
# 204.853 224.026
# 181.463 300.53
# 129.397 238.48
# 168.601 218.504
# 141.243 236.957
# 173.063 268.777
# 213.33 359.218
# 282.759 328.306
# 264.405 302.093
# 254.013 296.093
# 168.501 327.217
# 205.588 312.233
# 155.943 273.446
# 224.887 331.297
# 287.46 368.895
# 255.64 337.075
# 160.475 309.787
# 90.554 322.116
# 32.682 248.043
# 25.629 238.335
# 14.094 241.643
# 400 250
# 424.967 181.402
# 486.462 135.062
# 435.608 191.541
# 405.852 273.294
# 355.046 268.849
# 364.585 284.114
# 429.088 336.348
# 374.095 385.864
# 350.428 436.617
# 325.42 410.721
# 320.049 333.909
# 289.74 309.366
# 312.111 359.611
# 317.473 403.283
# 308.118 424.295
# 270.038 393.458
# 283.934 391.752
# 361.558 411.106
# 356.215 383.62
# 411.968 367.633
# 319.544 332.155
# 356.086 315.886
# 419.998 269.451
# 434.077 358.343
# 452.075 379.792
# 458.804 354.678
# 447.0 331.512
# 441.669 280.791
# 459.504 264.732
# 489.55 321.241
# 456.12 341.327
# 500.754 330.199
# 553.59 364.511
# 600.003 295.701
# 600.003 344.701
# 588.26 308.561
# 578.516 310.811
# 598.372 303.974
# 621.538 315.778
# 672.964 328.6
# 709.583 259.73
# 701.905 322.26
# 668.767 308.194
# 614.619 328.979
# 642.738 278.251
# 645.879 368.196
# 583.585 321.254
# 634.58 300.651
# 701.99 267.773
# 619.301 308.103
# 639.761 330.044
# 639.761 234.044
# 713.936 204.075
# 680.021 149.8
# 704.131 199.234
# 683.529 233.521
# 731.062 226.841
# 788.35 165.407
# 745.087 237.409
# 712.097 245.634
# 741.45 264.696
# 734.589 232.417
# 733.281 207.451
# 705.235 284.506
# 674.367 357.226
# 687.359 357.68
# 703.111 368.305
# 610.465 360.2
# 553.107 310.34
# 630.143 274.417
# 607.186 286.623
# 597.073 338.649
# 580.753 325.433
# 640.67 344.901
# 641.42 301.908
# 625.964 267.193
# 617.416 304.219
# 622.12 348.972
# 702.676 357.439
# 689.653 395.26
# 687.458 374.375
# 770.256 368.585
# 757.045 379.283
# 753.278 325.415
# 726.4 255.396
# 638.752 239.941
# 661.414 277.656
# 664.998 286.992
# 663.968 345.983
# 746.182 300.411
# 400 250
# 393.71 224.772
# 381.799 223.31
# 451.788 224.532
# 428.096 185.102
# 442.82 182.24
# 455.323 152.784
# 401.948 234.974
# 430.116 181.997
# 412.535 130.939
# 455.391 154.695
# 466.719 168.684
# 532.879 137.833
# 539.825 177.225
# 565.261 94.026
# 473.674 77.877
# 567.749 91.098
# 564.052 38.227
# 615.96 53.111
# 668.429 30.839
# 680.863 40.908
# 685.733 52.961
# 646.786 50.92
# 400 250
# 346.296 255.645
# 380.258 285.168
# 364.609 278.526
# 338.835 267.586
# 276.818 297.834
# 303.085 254.118
# 307.411 267.433
# 365.697 220.234
# 329.171 190.656
# 356.571 231.279
# 331.713 216.343
# 306.85 213.73
# 300.664 195.765
# 308.762 160.688
# 294.057 67.845
# 346.569 118.555
# 283.494 162.72
# 318.282 187.995
# 294.799 172.745
# 344.531 126.369
# 421.468 64.066
# 345.638 77.437
# 268.562 32.937
# 400 250
# 356.904 194.839
# 378.868 244.17
# 405.048 196.941
# 409.932 211.124
# 397.808 204.124
# 446.665 242.295
# 441.697 299.078
# 472.097 342.493
# 439.963 391.975
# 490.591 370.485
# 396.387 343.473
# 428.712 395.204
# 521.86 418.429
# 522.768 470.421
# 400 250
# 408.343 275.679
# 443.771 312.365
# 486.805 325.522
# 465.834 326.621
# 518.892 290.833
# 502.088 297.284
# 491.949 200.815
# 497.701 135.066
# 501.71 180.891
# 476.725 181.763
# 429.083 187.613
# 495.338 230.639
# 483.709 198.689
# 465.982 195.563
# 461.272 285.44
# 452.822 301.333
# 427.45 292.098
# 338.121 303.066
# 374.184 279.647
# 417.651 268.0
# 361.864 263.119
# 360.382 246.184
# 322.784 183.611
# 384.827 194.551
# 412.402 189.689
# 360.724 216.02
# 358.351 148.061
# 391.489 162.127
# 397.907 253.903
# 390.405 261.948
# 394.229 245.384
# 486.02 208.298
# 473.763 218.583
# 438.092 250.701
# 528.301 212.409
# 553.207 252.267
# 583.736 257.65
# 565.8 349.923
# 547.568 402.872
# 472.94 356.239
# 452.079 336.094
# 425.326 312.005
# 399.018 305.931
# 399.018 285.931
# 464.55 331.817
# 468.292 314.21
# 402.106 291.42
# 407.338 216.603
# 379.842 241.361
# 395.385 228.775
# 384.015 235.078
# 365.592 201.842
# 440.234 250.315
# 450.298 243.779
# 467.55 277.637
# 487.084 334.368
# 476.896 286.439
# 476.024 261.454
# 441.521 329.17
# 484.293 356.947
# 564.01 404.846
# 598.615 394.923
# 626.829 433.756
# 650.123 494.439
# 690.625 477.247
# 641.838 497.956
# 657.719 496.006
# 677.282 491.848
# 400 250
# 398.674 287.977
# 409.312 220.814
# 336.223 209.238
# 270.648 282.066
# 300.131 291.646
# 294.922 276.518
# 309.179 285.777
# 291.198 330.282
# 322.311 361.395
# 311.915 410.302
# 267.681 441.275
# 400 250
# 413.766 163.083
# 453.76 162.385
# 470.962 150.34
# 498.13 157.114
# 455.001 241.76
# 515.378 189.275
# 516.041 170.287
# 511.631 185.667
# 477.393 174.542
# 534.423 137.507
# 608.139 93.214
# 660.933 38.544
# 603.251 32.481
# 570.284 49.279
# 529.5 30.261
# 400 250
# 325.139 191.512
# 360.81 223.63
# 383.041 284.71
# 417.78 288.975
# 377.077 265.475
# 392.316 229.575
# 310.965 282.405
# 246.212 288.07
# 306.888 332.154
# 318.013 366.392
# 329.462 425.29
# 336.089 330.521
# 325.171 329.18
# 345.35 384.622
# 356.183 386.532
# 432.737 415.918
# 389.166 483.012
# 400 250
# 388.773 302.82
# 399.539 241.762
# 406.047 227.145
# 454.047 310.283
# 477.794 290.357
# 547.547 327.445
# 615.875 317.842
# 647.422 272.789
# 613.945 328.505
# 586.445 280.874
# 622.116 312.992
# 630.097 328.002
# 608.949 334.066
# 681.239 323.906
# 632.9 293.701
# 585.405 333.554
# 541.112 259.838
# 532.645 225.878
# 566.289 235.525
# 509.367 238.508
# 496.685 285.838
# 503.495 299.203
# 485.027 234.798
# 524.445 209.2
# 549.839 135.45
# 543.738 205.184
# 477.758 188.733
# 479.102 265.721
# 454.587 313.835
# 483.717 303.232
# 490.606 292.207
# 464.426 244.978
# 480.169 236.251
# 541.028 199.683
# 638.491 189.439
# 623.036 277.087
# 634.449 280.795
# 570.602 245.404
# 589.313 242.105
# 642.679 228.799
# 664.951 281.268
# 661.009 291.537
# 669.894 207.003
# 622.263 179.503
# 604.103 143.863
# 567.009 203.226
# 552.925 176.738
# 537.989 151.88
# 505.736 67.858
# 437.659 138.353
# 497.499 186.811
# 530.592 198.206
# 495.379 205.691
# 583.676 183.676
# 646.745 199.401
# 630.344 180.533
# 583.652 147.839
# 589.051 171.224
# 540.57 83.762
# 517.566 127.026
# 484.279 137.842
# 437.915 150.265
# 408.321 223.513
# 346.885 266.531
# 311.637 232.493
# 335.91 223.175
# 402.793 162.953
# 437.064 98.498
# 444.57 70.486
# 458.806 160.366
# 484.518 129.724
# 505.12 95.437
# 527.001 43.889
# 503.49 76.25
# 499.579 100.942
# 476.921 90.377
# 429.36 133.201
# 473.536 198.695
# 434.635 158.412
# 454.623 159.11
# 458.781 139.547
# 378.569 150.82
# 301.594 168.591
# 359.162 161.523
# 292.279 221.745
# 221.064 290.516
# 312.714 298.534
# 326.214 202.478
# 312.793 222.375
# 245.596 250.898
# 257.203 258.727
# 213.75 189.187
# 246.696 115.19
# 200.332 127.613
# 183.336 75.305
# 400 250
# 420.726 263.98
# 420.726 218.98
# 421.529 195.994
# 491.007 204.525
# 468.38 181.898
# 456.81 168.109
# 380.629 114.766
# 359.098 28.41
# 302.585 41.457
# 310.973 53.893
# 313.223 10.952
# 400 250
# 391.759 270.398
# 338.832 267.624
# 352.029 342.469
# 365.229 391.731
# 329.176 451.733
# 400 250
# 442.343 267.974
# 363.704 323.037
# 358.47 422.9
# 317.09 361.551
# 385.479 306.171
# 396.511 297.552
# 412.271 249.048
# 414.363 225.139
# 458.794 187.857
# 397.983 127.046
# 406.615 118.71
# 429.493 198.495
# 448.072 215.223
# 455.674 190.359
# 448.554 230.736
# 407.953 236.442
# 353.889 198.586
# 396.947 262.422
# 404.132 247.015
# 478.774 198.542
# 519.051 248.279
# 480.913 170.084
# 463.855 189.706
# 489.821 148.152
# 512.611 214.338
# 517.433 204.451
# 601.435 153.977
# 541.216 183.348
# 583.502 198.739
# 525.113 265.908
# 459.926 276.233
# 392.434 261.887
# 387.933 176.005
# 315.531 214.502
# 244.811 157.234
# 201.987 204.795
# 196.127 121.0
# 129.44 190.057
# 117.375 288.319
# 104.795 338.774
# 104.795 250.774
# 109.182 286.506
# 108.274 338.498
# 46.658 314.846
# 98.733 269.578
# 192.375 277.771
# 228.841 254.984
# 274.695 322.965
# 326.767 299.781
# 350.602 355.932
# 321.863 267.484
# 359.857 266.821
# 303.857 266.821
# 209.782 280.042
# 187.383 232.008
# 175.807 158.919
# 210.589 196.218
# 216.03 118.408
# 268.096 180.458
# 185.21 176.114
# 186.955 276.099
# 168.414 306.957
# 119.852 332.778
# 196.176 285.085
# 173.386 218.899
# 91.955 169.97
# 136.719 189.9
# 140.951 202.192
# 210.43 137.402
# 221.545 125.893
# 231.079 107.182
# 169.406 31.022
# 193.088 108.483
# 175.112 99.716
# 169.159 121.932
# 207.921 158.078
# 282.527 218.493
# 317.91 207.675
# 333.295 280.058
# 345.103 213.091
# 387.313 204.886
# 365.262 127.985
# 385.957 217.627
# 357.7 211.103
# 328.018 192.556
# 358.487 165.122
# 384.918 197.762
# 389.924 229.368
# 378.574 251.643
# 397.548 252.637
# 415.866 346.873
# 339.558 367.32
# 249.117 407.587
# 260.232 396.078
# 173.299 372.784
# 156.37 364.158
# 109.252 373.317
# 30.536 416.95
# 15.389 424.668
# 16.785 344.68
# 400 250
# 414.643 217.112
# 430.376 256.054
# 439.784 166.547
# 477.64 220.611
# 477.64 315.611
# 410.122 388.015
# 389.449 315.92
# 305.162 276.617
# 363.411 234.296
# 356.769 249.945
# 372.14 261.113
# 409.676 289.398
# 455.701 308.935
# 452.911 348.838
# 419.368 323.562
# 502.457 369.619
# 465.366 357.567
# 398.53 429.24
# 400 250
# 366.021 248.813
# 397.895 296.068
# 384.92 229.317
# 389.31 271.087
# 428.944 303.182
# 396.583 326.693
# 303.81 320.206
# 291.131 275.988
# 317.486 256.128
# 270.906 309.712
# 208.15 348.926
# 210.587 329.075
# 197.809 319.446
# 182.774 324.918
# 170.247 305.629
# 129.478 222.041
# 162.574 247.899
# 120.253 306.148
# 175.066 330.552
# 135.47 371.554
# 124.344 367.059
# 70.144 306.864
# 400 250
# 388.393 242.171
# 383.164 182.399
# 462.902 214.615
# 451.914 191.051
# 484.914 248.209
# 576.964 287.282
# 567.148 289.19
# 594.348 267.164
# 650.499 243.329
# 661.092 303.402
# 677.151 321.237
# 766.678 281.377
# 741.092 251.943
# 703.785 226.779
# 675.262 159.582
# 636.949 179.104
# 667.851 230.534
# 632.685 313.379
# 673.934 260.582
# 685.284 282.857
# 718.887 203.694
# 717.561 165.717
# 663.469 180.211
# 587.198 128.765
# 602.654 94.05
# 570.785 73.354
# 589.817 64.479
# 535.939 6.702
# 400 250
# 440.844 246.427
# 440.076 268.414
# 436.936 328.332
# 452.032 318.528
# 375.138 322.558
# 335.736 372.991
# 267.399 438.984
# 282.546 431.266
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-35-4c70699c5549> in <module>
#       9   turtle.left(random.randint(0,360))
#      10   turtle.color((random.randint(0,255),random.randint(0,255),random.randint(0,255)))
# ---> 11   turtle.forward(random.randint(10,100))
#      12   if 800 <= turtle.getx() or turtle.getx() <= 0 or \
#      13   500 <= turtle.gety() or turtle.gety() <=0:
#
# /usr/local/lib/python3.7/dist-packages/ColabTurtle/Turtle.py in forward(units)
#     172     ending_point = (turtle_pos[0] + units * math.cos(alpha), turtle_pos[1] + units * math.sin(alpha))
#     173
# --> 174     _moveToNewPosition(ending_point)
#     175
#     176 fd = forward # alias
#
# /usr/local/lib/python3.7/dist-packages/ColabTurtle/Turtle.py in _moveToNewPosition(new_pos)
#     161
#     162     turtle_pos = new_pos
# --> 163     _updateDrawing()
#     164
#     165
#
# /usr/local/lib/python3.7/dist-packages/ColabTurtle/Turtle.py in _updateDrawing()
#     143     if drawing_window == None:
#     144         raise AttributeError("Display has not been initialized yet. Call initializeTurtle() before using.")
# --> 145     time.sleep(_speedToSec(turtle_speed))
#     146     drawing_window.update(HTML(_generateSvgDrawing()))
#     147
#
# KeyboardInterrupt:
